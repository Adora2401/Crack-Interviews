# %%
# This is the serie of 2 sum
# 1.Two Sum
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        hashmap = {}
        for i in range(len(nums)):
            rest = target - nums[i]
            if rest in hashmap:
                return [hashmap[rest], i]
            hashmap[nums[i]] = i
# 167. Two Sum II - Input Array Is Sorted
# 遇见sorted array 先想2 pointer
class Solution:
    def twoSum(self, numbers: List[int], target: int) -> List[int]:
        left, right = 0, len(numbers) - 1
        while left < right:
            sumN = numbers[left] + numbers[right]
            if sumN == target:
                return [left+1, right+1]
            elif sumN > target:
                right -= 1
            else:
                left += 1
# 170. Two Sum III - Data structure design
# Solution 1:
class TwoSum:

    def __init__(self):
        self.nums = []
        self.sorted = False

    def add(self, number: int) -> None: #O(1)
        self.nums.append(number)
        self.sorted = False

    def find(self, value: int) -> bool: #O(nlogn)
        if not self.sorted:
            self.nums.sort()
            self.sorted = True
        left, right = 0, len(self.nums) - 1
        while left < right:
            currSum = self.nums[left] + self.nums[right]
            if currSum == value:
                return True
            elif currSum > value:
                right -= 1
            else:
                left += 1
        return False
#Solution 2:
class TwoSum:

    def __init__(self):
        self.hashmap = {}

    def add(self, number: int) -> None: #O(1)
        if number in self.hashmap:
            self.hashmap[number] += 1
        else:
            self.hashmap[number] = 1

    def find(self, value: int) -> bool: #O(N)
        for num in self.hashmap.keys():
            rest = value - num
            if rest != num:
                if rest in self.hashmap:
                    return True
            elif self.hashmap[rest] > 1:
                return True
        return False
# Your TwoSum object will be instantiated and called as such:
# obj = TwoSum()
# obj.add(number)
# param_2 = obj.find(value)


# 15. 3Sum
class Solution:
    def __init__(self):
        self.res = []
    def twoSum(self, nums, i): #O(n)
        if nums[i] > 0:
            return
        left, right = i + 1, len(nums) - 1
        while left < right:
            curSum = nums[i] + nums[left] + nums[right]
            if curSum == 0:
                self.res.append([nums[i], nums[left], nums[right]])
                left += 1
                right -= 1
                while left < right and nums[left] == nums[left - 1]:
                    left += 1
                while left < right and nums[right] == nums[right+1]:
                    right -= 1
            elif curSum > 0:
                right -= 1
            else:
                left += 1
    def threeSum(self, nums: List[int]) -> List[List[int]]: #O(nlogn + n^2)
        nums.sort()
        if nums[-1] < 0 or nums[0] > 0 or len(nums) < 3:
            return []
        for i in range(len(nums)):
            if i == 0 or nums[i] != nums[i-1]:
                self.twoSum(nums, i)
        return self.res
# 18. 4Sum
class Solution:
    def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
        def kSum(nums, target, k):
            res = []
            if not nums:
                return res
            avg = target // k
            if avg < nums[0] or avg > nums[-1]:
                return res
            if k == 2:
                return twoSum(nums, target)
            for i in range(len(nums)):
                if i == 0 or nums[i-1] != nums[i]:
                    for subset in kSum(nums[i+1:], target- nums[i], k-1):
                        res.append([nums[i]]+subset)
            return res
        def twoSum(nums, target):
            res = []
            left, right = 0, len(nums) -1
            while left < right:
                curr_sum = nums[left] + nums[right]
                if curr_sum == target:
                    res.append([nums[left], nums[right]])
                    left += 1
                    right -= 1
                    while left < right and nums[left -1] == nums[left]:
                        left += 1
                    while left < right and nums[right + 1] == nums[right]:
                        right -= 1
                elif curr_sum < target:
                    left += 1
                else:
                    right -= 1
            return res
        nums.sort()
        return kSum(nums,target, 4)
